# %%
import os
import cv2
from deepface import DeepFace
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from time import time

# Local descriptors
from skimage.feature import hog, local_binary_pattern
from skimage import exposure
from skimage import feature

# Classifiers
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score, accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier

# %%
def GetPredictions(X_train, X_test, y_train, y_test, model, parameters):
    model_name = type(model).__name__
    print(f"{model_name} training...")
    t0 = time()
    
    # Grid search across parameter range
    clf = GridSearchCV(model, parameters, cv=5)
    clf = clf.fit(X_train, y_train)
    print("done in %0.3fs" % (time() - t0))
    print("Best estimator found by grid search:")
    print(clf.best_estimator_)

    print("Predicting")
    t0 = time()
    # test labels
    y_pred = clf.predict(X_test)
   
    print("done in %0.3fs" % (time() - t0))
    
    return y_pred, y_test

# %%
def calc_embs(model, X):
    norm_images = prewhiten(X)
    pd = []
    for image in norm_images:
        pd.append(model.forward(np.expand_dims(image, axis=0))[0])
    return l2_normalize(np.vstack(pd))

def l2_normalize(x, axis=-1, epsilon=1e-10):
    output = x / np.sqrt(np.maximum(np.sum(np.square(x), axis=axis, keepdims=True), epsilon))
    return output

def prewhiten(x):
    if x.ndim == 4:
        axis = (1, 2, 3)
        size = x[0].size
    elif x.ndim == 3:
        axis = (0, 1, 2)
        size = x.size
    else:
        raise ValueError('Dimension should be 3 or 4')

    mean = np.mean(x, axis=axis, keepdims=True)
    std = np.std(x, axis=axis, keepdims=True)
    std_adj = np.maximum(std, 1.0/np.sqrt(size))
    y = (x - mean) / std_adj
    return y

def save_image_with_error_handling(dest_folder, class_name, n_images, image):
    try:
        # Apply CLAHE
        clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
        image = clahe.apply(image)
        
        cv2.imwrite(os.path.join(dest_folder, os.path.join(class_name, str(n_images) + '_faces.jpg')), image)
    except cv2.error as e:
        print(f"An error occurred while saving image {str(n_images)}: {e}")

# %%
# Data location
folder = "C:/Users/Sobieski/Desktop/Projekte/Gesichtserkennung/rvf10k"
dest_folder = "C:/Users/Sobieski/Desktop/Projekte/Gesichtserkennung/roi_dataset"
cascade_path = "haarcascade_frontalface_default.xml"

# Counter for the number of classes in the dataset
nclasses = 0
# Counter for samples per class
nperclass = []
# Label for each class (name of the subfolder)
classlabels = []

n_images = 0

# Assumes that there is a subfolder per class in the given path
for class_name in os.listdir(folder):
    # Each subfolder implies one more class
    nclasses += 1
    # Initially, this class has no samples
    nsamples = 0

    # Compose the path
    class_folder = os.path.join(folder, class_name)
    for file_name in os.listdir(class_folder):
        # Assumes images are in jpg format
        if file_name.endswith('.jpg'):
            # Read the image
            image = cv2.imread(os.path.join(class_folder, file_name))

            # Extract face as ROI
            faceCascade = cv2.CascadeClassifier(cascade_path)
            faces = faceCascade.detectMultiScale(
                image,
                scaleFactor=1.3,
                minNeighbors=5,
                minSize=(30, 30)
            )

            if len(faces) > 0:
                for x, y, w, h in faces:
                    face = image[y:y + h, x:x + w]
                    save_image_with_error_handling(dest_folder, class_name, n_images, face)
                    n_images += 1
            else:
                cv2.imwrite(
                    os.path.join(dest_folder, os.path.join(class_name, str(n_images) + '_faces.jpg')), image)
                n_images += 1

# Deepface
model_deepface = DeepFace.build_model("ArcFace")

# Check the input shape structure
print(model_deepface.input_shape)

# Adjust target_size based on input_shape structure
if len(model_deepface.input_shape) == 4:
    target_size = (model_deepface.input_shape[1], model_deepface.input_shape[2])
else:
    target_size = (model_deepface.input_shape[0], model_deepface.input_shape[1])

dim = (int(target_size[0]), int(target_size[1]))

# Data location
folder = "roi_dataset"

# Counter for the number of classes in the dataset
nclasses = 0
# Counter for samples per class
nperclass = []
# Label for each class (name of the subfolder)
classlabels = []
# Initialize data structures and their corresponding labels
X = []
Y = []
XFaceNet = []

# Default resolution value for matplotlib
dpi = matplotlib.rcParams['figure.dpi']
# Number of sample images from each class to show
nims2show = 5

# Assumes that there is a subfolder per class in the given path
for class_name in os.listdir(folder):
    # Each subfolder implies one more class
    nclasses += 1
    # Initially, this class has no samples
    nsamples = 0

    # Compose the path
    class_folder = os.path.join(folder, class_name)
    for file_name in os.listdir(class_folder):
        # Assumes images are in jpg format
        if file_name.endswith('.jpg'):
            # Read the image
            image = cv2.imread(os.path.join(class_folder, file_name))
            
            # Extract sizes
            height, width, depth = image.shape
            # Convert to grayscale
            gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            X.append(gray.reshape(height * width))
            
            # Deepface with ArcFace
            # Get embeddings
            img_embedding = cv2.resize(image, dim, interpolation=cv2.INTER_AREA)
            img_embedding = calc_embs(model_deepface, np.expand_dims(img_embedding, axis=0))
            XFaceNet.append(img_embedding[0])
                    
            # Add numerical label of the sample
            Y.append(nclasses - 1)
            
            # Show the first nims2show samples of each class
            if nsamples < nims2show:
                if nsamples == 0:
                    figsize = 15 * width / float(dpi), 15 * height / float(dpi)
                    fig = plt.figure(figsize=figsize)
                
                fig.add_subplot(1, nims2show, nsamples + 1)
                plt.imshow(gray, cmap='gray', vmin=0, vmax=255)
            
            # Increase the number of samples
            nsamples += 1
    plt.show()
    nperclass.append(nsamples)
    classlabels.append(class_name)
# Out:
# (112, 112)

# %%
# Convert X and Y to numpy arrays
Y = np.array(Y, dtype='float64')
XFaceNet = np.array(XFaceNet, dtype='float32')

# Show information about the read dataset
# Debugging
print("Features")
print(XFaceNet.shape)
print(Y.shape)
# Get number of samples and features
# Get names of the classes
class_names = np.array(classlabels)
n_classes = class_names.shape[0]
# StratifiedKFold
skf = StratifiedKFold(n_splits=5, random_state=7, shuffle=True)

fold = 1
for train_index, test_index in skf.split(X, Y):
    #print("TRAIN:", train_index, "TEST:", test_index)
    print("Fold %d" % fold)
    print("# samples in training set %d" % train_index.shape[0])
    print("# samples in test set %d" % test_index.shape[0])
    fold += 1
# Out:
# Features
# (7002, 1)
# (7002,)
# Fold 1
# # samples in training set 5601
# # samples in test set 1401
# Fold 2
# # samples in training set 5601
# # samples in test set 1401
# Fold 3
# # samples in training set 5602
# # samples in test set 1400
# Fold 4
# # samples in training set 5602
# # samples in test set 1400
# Fold 5
# # samples in training set 5602
# # samples in test set 1400

# %%
print("+++++++++++++++++++++++++++++++++++++++++++\n")

# KNN 
precs_facenet_svm, recs_facenet_svm, acc_facenet_svm = [], [], []

precs_facenet_rf, recs_facenet_rf, acc_facenet_rf = [], [], []

SVM = SVC(kernel='rbf', class_weight='balanced')
SVM_parameters = {
    'C': [1e3, 5e3],
    'gamma': [0.0001, 0.0005, 0.001, 0.005, 0.01],
}

RF = RandomForestClassifier()
RF_parameters = {
    'n_estimators': [100, 150, 200],
}

fold = 1
for train_index, test_index in skf.split(X, Y):
    print("Fold %d" % fold)
    print("# samples in training set %d" % train_index.shape[0])
    print("# samples in test set %d" % test_index.shape[0])
    
    XFaceNet_reshaped = XFaceNet.reshape(len(XFaceNet), -1)
    
    y_pred, y_test = GetPredictions(XFaceNet_reshaped[train_index], XFaceNet_reshaped[test_index], Y[train_index], Y[test_index], SVM, SVM_parameters)
    precs_facenet_svm.append(precision_score(y_test, y_pred, average='weighted'))
    recs_facenet_svm.append(recall_score(y_test, y_pred, average='weighted'))
    acc_facenet_svm.append(accuracy_score(y_test, y_pred))
    
    y_pred, y_test = GetPredictions(XFaceNet_reshaped[train_index], XFaceNet_reshaped[test_index], Y[train_index], Y[test_index], RF, RF_parameters)
    precs_facenet_rf.append(precision_score(y_test, y_pred, average='weighted'))
    recs_facenet_rf.append(recall_score(y_test, y_pred, average='weighted'))
    acc_facenet_rf.append(accuracy_score(y_test, y_pred))
    
    fold += 1

print("Facenet SVM precision: ", np.mean(precs_facenet_svm))
print("Facenet SVM recall: ", np.mean(recs_facenet_svm))
print("Facenet SVM accuracy: ", np.mean(acc_facenet_svm))

print("Facenet RF precision: ", np.mean(precs_facenet_rf))
print("Facenet RF recall: ", np.mean(recs_facenet_rf))
print("Facenet RF accuracy: ", np.mean(acc_facenet_rf))
# Out:
# +++++++++++++++++++++++++++++++++++++++++++
#
# Fold 1
# # samples in training set 5601
# # samples in test set 1401
# SVC training...
# done in 22.674s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.0001)
# Predicting
# done in 0.322s
# RandomForestClassifier training...
# done in 2.147s
# Best estimator found by grid search:
# RandomForestClassifier(n_estimators=200)
# Predicting
# done in 0.006s
# Fold 2
# # samples in training set 5601
# # samples in test set 1401
# SVC training...
# done in 23.474s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.0001)
# Predicting
# done in 0.385s
# RandomForestClassifier training...
# done in 2.189s
# Best estimator found by grid search:
# RandomForestClassifier()
# Predicting
# done in 0.004s
# Fold 3
# # samples in training set 5602
# # samples in test set 1400
# SVC training...
# done in 22.342s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.0001)
# Predicting
# done in 0.350s
# RandomForestClassifier training...
# done in 2.202s
# Best estimator found by grid search:
# RandomForestClassifier(n_estimators=200)
# Predicting
# done in 0.007s
# Fold 4
# # samples in training set 5602
# # samples in test set 1400
# SVC training...
# done in 23.569s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.0001)
# Predicting
# done in 0.346s
# RandomForestClassifier training...
# done in 2.204s
# Best estimator found by grid search:
# RandomForestClassifier(n_estimators=150)
# Predicting
# done in 0.005s
# Fold 5
# # samples in training set 5602
# # samples in test set 1400
# SVC training...
# done in 22.706s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.0001)
# Predicting
# done in 0.314s
# RandomForestClassifier training...
# done in 2.047s
# Best estimator found by grid search:
# RandomForestClassifier()
# Predicting
# done in 0.004s
# Facenet SVM precision:  0.6298622233284672
# Facenet SVM recall:  0.5017136739063934
# Facenet SVM accuracy:  0.5017136739063934
# Facenet RF precision:  0.6298622233284672
# Facenet RF recall:  0.5017136739063934
# Facenet RF accuracy:  0.5017136739063934

# %%
print("+++++++++++++++++++++++++++++++++++++++++++\n")

# KNN 
precs_facenet_svm, recs_facenet_svm, acc_facenet_svm = [], [], []

precs_facenet_rf, recs_facenet_rf, acc_facenet_rf = [], [], []


SVM = SVC(kernel='rbf', class_weight='balanced')
SVM_parameters = {
    'C': [1e3, 5e3],
    'gamma': [0.0001, 0.0005, 0.001, 0.005, 0.01],
}

RF = RandomForestClassifier()
RF_parameters = {
    'n_estimators': [100, 150, 200],
}

fold = 1
for train_index, test_index in skf.split(X, Y):
    #print("TRAIN:", train_index, "TEST:", test_index)
    print("*********************\nFold %d" % fold)
        
    #Facenet - SVM
    print("\nDeepface/ArcFace")
    XFaceNet=XFaceNet.reshape(-1, 1)
    y_pred, y_test = GetPredictions(XFaceNet[train_index], XFaceNet[test_index],Y[train_index], Y[test_index], SVM, SVM_parameters)
    print("\nDeepface/ArcFace + SVM Metrics")
    precs_facenet_svm.append(precision_score(y_test, y_pred))
    recs_facenet_svm.append(recall_score(y_test, y_pred))
    acc_facenet_svm.append(accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred, target_names=class_names))
    if fold == 1:
        print("Confussion matrix:")
        print(confusion_matrix(y_test, y_pred, labels=range(n_classes)))
        
    #Facenet - Random Forest
    y_pred, y_test = GetPredictions(XFaceNet[train_index], XFaceNet[test_index],Y[train_index], Y[test_index], RF, RF_parameters)
    print("\nDeepface/ArcFace + RF Metrics")
    precs_facenet_rf.append(precision_score(y_test, y_pred))
    recs_facenet_rf.append(recall_score(y_test, y_pred))
    acc_facenet_rf.append(accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred, target_names=class_names))
    if fold == 1:
        print("Confussion matrix:")
        print(confusion_matrix(y_test, y_pred, labels=range(n_classes))) 
    fold += 1
# Out:
# +++++++++++++++++++++++++++++++++++++++++++
#
# *********************
# Fold 1
#
# Deepface/ArcFace
# SVC training...
# done in 22.950s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.0001)
# Predicting
# done in 0.321s
#
# Deepface/ArcFace + SVM Metrics
#               precision    recall  f1-score   support
#
#         fake       0.50      1.00      0.67       701
#         real       0.78      0.01      0.02       700
#
#     accuracy                           0.50      1401
#    macro avg       0.64      0.50      0.34      1401
# weighted avg       0.64      0.50      0.34      1401
#
# Confussion matrix:
# [[699   2]
#  [693   7]]
# RandomForestClassifier training...
# done in 2.140s
# Best estimator found by grid search:
# RandomForestClassifier(n_estimators=150)
# Predicting
# done in 0.005s
#
# Deepface/ArcFace + RF Metrics
#               precision    recall  f1-score   support
#
#         fake       0.50      1.00      0.67       701
#         real       0.78      0.01      0.02       700
#
#     accuracy                           0.50      1401
#    macro avg       0.64      0.50      0.34      1401
# weighted avg       0.64      0.50      0.34      1401
#
# Confussion matrix:
# [[699   2]
#  [693   7]]
# *********************
# Fold 2
#
# Deepface/ArcFace
# SVC training...
# done in 22.822s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.0001)
# Predicting
# done in 0.315s
#
# Deepface/ArcFace + SVM Metrics
#               precision    recall  f1-score   support
#
#         fake       0.50      1.00      0.67       700
#         real       0.60      0.00      0.01       701
#
#     accuracy                           0.50      1401
#    macro avg       0.55      0.50      0.34      1401
# weighted avg       0.55      0.50      0.34      1401
#
# RandomForestClassifier training...
# done in 2.057s
# Best estimator found by grid search:
# RandomForestClassifier()
# Predicting
# done in 0.004s
#
# Deepface/ArcFace + RF Metrics
#               precision    recall  f1-score   support
#
#         fake       0.50      1.00      0.67       700
#         real       0.60      0.00      0.01       701
#
#     accuracy                           0.50      1401
#    macro avg       0.55      0.50      0.34      1401
# weighted avg       0.55      0.50      0.34      1401
#
# *********************
# Fold 3
#
# Deepface/ArcFace
# SVC training...
# done in 22.390s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.0001)
# Predicting
# done in 0.344s
#
# Deepface/ArcFace + SVM Metrics
#               precision    recall  f1-score   support
#
#         fake       0.50      1.00      0.67       700
#         real       0.75      0.00      0.01       700
#
#     accuracy                           0.50      1400
#    macro avg       0.63      0.50      0.34      1400
# weighted avg       0.63      0.50      0.34      1400
#
# RandomForestClassifier training...
# done in 2.076s
# Best estimator found by grid search:
# RandomForestClassifier()
# Predicting
# done in 0.004s
#
# Deepface/ArcFace + RF Metrics
#               precision    recall  f1-score   support
#
#         fake       0.50      1.00      0.67       700
#         real       0.75      0.00      0.01       700
#
#     accuracy                           0.50      1400
#    macro avg       0.63      0.50      0.34      1400
# weighted avg       0.63      0.50      0.34      1400
#
# *********************
# Fold 4
#
# Deepface/ArcFace
# SVC training...
# done in 22.298s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.0001)
# Predicting
# done in 0.312s
#
# Deepface/ArcFace + SVM Metrics
#               precision    recall  f1-score   support
#
#         fake       0.50      1.00      0.67       700
#         real       0.67      0.00      0.01       700
#
#     accuracy                           0.50      1400
#    macro avg       0.58      0.50      0.34      1400
# weighted avg       0.58      0.50      0.34      1400
#
# RandomForestClassifier training...
# done in 2.125s
# Best estimator found by grid search:
# RandomForestClassifier(n_estimators=150)
# Predicting
# done in 0.005s
#
# Deepface/ArcFace + RF Metrics
#               precision    recall  f1-score   support
#
#         fake       0.50      1.00      0.67       700
#         real       0.67      0.00      0.01       700
#
#     accuracy                           0.50      1400
#    macro avg       0.58      0.50      0.34      1400
# weighted avg       0.58      0.50      0.34      1400
#
# *********************
# Fold 5
#
# Deepface/ArcFace
# SVC training...
# done in 22.420s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.0001)
# Predicting
# done in 0.315s
#
# Deepface/ArcFace + SVM Metrics
#               precision    recall  f1-score   support
#
#         fake       0.50      1.00      0.67       700
#         real       1.00      0.00      0.01       700
#
#     accuracy                           0.50      1400
#    macro avg       0.75      0.50      0.34      1400
# weighted avg       0.75      0.50      0.34      1400
#
# RandomForestClassifier training...
# done in 2.074s
# Best estimator found by grid search:
# RandomForestClassifier()
# Predicting
# done in 0.004s
#
# Deepface/ArcFace + RF Metrics
#               precision    recall  f1-score   support
#
#         fake       0.50      1.00      0.67       700
#         real       1.00      0.00      0.01       700
#
#     accuracy                           0.50      1400
#    macro avg       0.75      0.50      0.34      1400
# weighted avg       0.75      0.50      0.34      1400
